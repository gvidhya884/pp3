# %%
l1=[1,2,"hi",[1,2],15.9]
print(l1)
# Out:
# [1, 2, 'hi', [1, 2], 15.9]

# %%
l1=[1,2,"hi",[1,2],15.9]
print(type(l1))
# Out:
# <class 'list'>

# %%
l1=[1,3,4,5,"hi",8]
l2=[3,5,2,"hi"]
print(l1==l2)
# Out:
# False
# [None]

# %%
l1=[1,3,4,5,"hi",8]
l2=[1,3,4,5,"hi",8]
print(l1==l2)
# Out:
# True

# %%
l=[1,2,3,4,5,6]
l[0:]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[:]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[2:7]
# Out:
# [3, 4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[3:]
# Out:
# [4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[:3]
# Out:
# [1, 2, 3]

# %%
l=[1,2,3,4,5,6]
l[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3122362212.py in <cell line: 0>()
#       1 l=[1,2,3,4,5,6]
# ----> 2 l[6]
#
# IndexError: list index out of range

# %%
l=[1,2,3,4,5,6]
print(l[5])
# Out:
# 6

# %%
l=[1,2,3,4,5,6]
print(l[-1])
# Out:
# 6

# %%
l=[1,2,3,4,5,6]
print(l[-5:-1])
# Out:
# [2, 3, 4, 5]

# %%
l=[1,2,3,4,5,6]
l[-3:]
# Out:
# [4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[:-1]
# Out:
# [1, 2, 3, 4, 5]

# %%
l=[1,2,3,4,5,6]
l[2]=55
print(l)
# Out:
# [1, 2, 55, 4, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[1:4]=[55,56,57]
print(l)
# Out:
# [1, 55, 56, 57, 5, 6]

# %%
l=[1,2,3,4,5,6]
l[-3:-1]=[55,56]
print(l)
# Out:
# [1, 2, 3, 55, 56, 6]

# %%
l=[1,2,3,4,5,6]
l1=l*2
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]

# %%
l1=[1,2,3,4,5,6]
l2=[8,9,10,11,12,13]
print(l1+l2)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13]

# %%
l2=[8,9,10,11,12,13]
print(len(l2))
# Out:
# 6

# %%
l2=[8,9,10,11,12,13]
for i in l2:
  print(i,end=",")
# Out:
# 8,9,10,11,12,13,

# %%
l2=[8,9,10,11,12,13]
print(10 in l2)
# Out:
# True

# %%
l2=[8,9,10,11,12,13]
print(10 not in l2)
# Out:
# False

# %%
l2=[8,9,10,11,12,13]
print(l2.append(89))
# Out:
# None

# %%
l2=[8,9,10,11,12,13,13]
print(l2)
# Out:
# [8, 9, 10, 11, 12, 13, 13]

# %%
l=[]
n=int(input())
for i in range(0,n):
  l.append(i)
print(l)
# Out:
# 4
# [0, 1, 2, 3]

# %%
l2=[8,9,10,11,12,13,13]
print(max(l2))
# Out:
# 13

# %%
l2=[8,9,10,11,12,13,13]
print(min(l2))
# Out:
# 8

# %%
import copy
a=[[1,2,3],"hi",[4,5,6]]
b=copy.copy(a)
print(b)
# Out:
# [[1, 2, 3], 'hi', [4, 5, 6]]

# %%
import copy
a=[[1,2,3],"hi",[4,5,6]]
b=copy.copy(a)
a.append([5,6,7])
print(a)
print(b)
# Out:
# [[1, 2, 3], 'hi', [4, 5, 6], [5, 6, 7]]
# [[1, 2, 3], 'hi', [4, 5, 6]]

# %%
import copy
a=[[1,2,3],"hi",[4,5,6]]
a.append([5,6,7])
b=copy.copy(a)

print(a)
print(b)
# Out:
# [[1, 2, 3], 'hi', [4, 5, 6], [5, 6, 7]]
# [[1, 2, 3], 'hi', [4, 5, 6], [5, 6, 7]]

# %%
import copy
a=[[1,2,3],"hi",[4,5,6]]
a.append([5,6,7])
print(a)
b=copy.copy(a)
print(b)
# Out:
# [[1, 2, 3], 'hi', [4, 5, 6], [5, 6, 7]]
# [[1, 2, 3], 'hi', [4, 5, 6], [5, 6, 7]]

# %%
import copy
a=[[1,2,3],[4,5,6],"hi"]
a[1][2]=55
print(a)
# Out:
# [[1, 2, 3], [4, 5, 55], 'hi']

# %%
a = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
b=copy.deepcopy(a)
b[1][0]="hi"
print(a)
# Out:
# [[1, 1, 1], [2, 2, 2], [3, 3, 3]]

# %%
a = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
b=copy.deepcopy(a)
b[1][0]="hi"
print(a)
print(b)
# Out:
# [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
# [[1, 1, 1], ['hi', 2, 2], [3, 3, 3]]
